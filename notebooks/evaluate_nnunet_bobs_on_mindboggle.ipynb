# %%
import os
import nibabel as nib
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# ----------------------------------------------------------------------
# 1) Define paths to ground truth, inference, and input directories
# ----------------------------------------------------------------------
minboggle_ground_truth_path = "/home/fp427/rds/rds-cam-segm-7tts6phZ4tw/mission/data/mindboggle/segmentation_nnunet_bobs_convention"
inference_22_path = "/home/fp427/rds/rds-cam-segm-7tts6phZ4tw/mission/nnunet/nnUNet_results/Dataset022_bobs/inferences"
input_path = "/home/fp427/rds/rds-cam-segm-7tts6phZ4tw/mission/data/mindboggle/input"

# ----------------------------------------------------------------------
# 2) Define label correspondence dictionary
# ----------------------------------------------------------------------
label_correspondence = {
    "labels": {
        "unknown": -1,
        "background": 0,
        "Left-Cerebral-Exterior": 1,
        "Cerebral-White-Matter": 2,
        "Cerebral-Cortex": 3,
        "Lateral-Ventricle": 4,
        "Inf-Lat-Vent": 5,
        "Left-Cerebellum-Exterior": 6,
        "Cerebellum-White-Matter": 7,
        "Cerebellum-Cortex": 8,
        "Thalamus": 9,
        "Caudate": 10,
        "Putamen": 11,
        "Pallidum": 12,
        "3rd-Ventricle": 13,
        "4th-Ventricle": 14,
        "Brain-Stem": 15,
        "Hippocampus": 16,
        "Amygdala": 17,
        "CSF": 18,
        "Accumbens-area": 19,
        "Vessel": 20,
        "Choroid-plexus": 21,
        "VentralDC": 22,
        "WM-hypointensities": 23,
        "Optic-Chiasm": 24,
        "Vermis": 25
    }
}

# ----------------------------------------------------------------------
# 3) Dice score functions
# ----------------------------------------------------------------------
def dice_score_per_label(gt_data, pred_data, label):
    """
    Compute the Dice score for a specific label.
    Dice = 2 * (|X ∩ Y|) / (|X| + |Y|)
    """
    gt_mask = (gt_data == label)
    pred_mask = (pred_data == label)

    intersection = np.logical_and(gt_mask, pred_mask).sum()
    gt_sum = gt_mask.sum()
    pred_sum = pred_mask.sum()

    # Avoid division by zero if both masks are empty
    if gt_sum + pred_sum == 0:
        return np.nan

    return 2.0 * intersection / (gt_sum + pred_sum)


def dice_score_all_labels(gt_data, pred_data, ignore_label=-1):
    """
    Compute the Dice score for each unique label in the ground truth,
    ignoring a specified label (default: -1).
    """
    unique_labels = np.unique(gt_data)
    dice_scores = {}
    for label in unique_labels:
        if label == ignore_label:
            continue
        dice_scores[label] = dice_score_per_label(gt_data, pred_data, label)
    return dice_scores


def dice_score_avg_foreground(gt_data, pred_data, ignore_label=-1, background_label=0):
    """
    Compute the average Dice score for all labels except the ignore_label and background_label.
    """
    unique_labels = np.unique(gt_data)
    dice_values = []
    for label in unique_labels:
        if label == ignore_label or label == background_label:
            continue
        score = dice_score_per_label(gt_data, pred_data, label)
        if not np.isnan(score):
            dice_values.append(score)

    if len(dice_values) == 0:
        return np.nan

    return np.mean(dice_values)

# ----------------------------------------------------------------------
# 4) List, sort, and pair .nii.gz files from each directory
# ----------------------------------------------------------------------
gt_files = [f for f in os.listdir(minboggle_ground_truth_path) if f.endswith('.nii.gz')]
inference_files = [f for f in os.listdir(inference_22_path) if f.endswith('.nii.gz')]

gt_files_sorted = sorted(gt_files)
inference_files_sorted = sorted(inference_files)

# Optional: Check if both directories have the same number of files
if len(gt_files_sorted) != len(inference_files_sorted):
    print("Warning: The number of files in ground truth and inference directories do not match.")

# ----------------------------------------------------------------------
# 5) Load and process up to 200 pairs of NIfTI files (Dice scores)
# ----------------------------------------------------------------------

### ADDED: A dictionary to accumulate Dice scores across all scans
### Key = label_id, Value = list of Dice scores from each scan
aggregate_scores = {}

num_pairs_to_load = 200
for i in range(min(num_pairs_to_load, len(gt_files_sorted), len(inference_files_sorted))):
    gt_filename = gt_files_sorted[i]
    inf_filename = inference_files_sorted[i]

    gt_filepath = os.path.join(minboggle_ground_truth_path, gt_filename)
    inf_filepath = os.path.join(inference_22_path, inf_filename)

    # Load the NIfTI images
    gt_img = nib.load(gt_filepath)
    inf_img = nib.load(inf_filepath)

    # Extract data as NumPy arrays
    gt_data = gt_img.get_fdata()
    inf_data = inf_img.get_fdata()

    # Compute Dice scores for each label (ignoring -1)
    dice_scores = dice_score_all_labels(gt_data, inf_data, ignore_label=-1)

    # Compute the average Dice over all foreground labels (removing 0 and -1)
    avg_foreground_dice = dice_score_avg_foreground(
        gt_data, inf_data, ignore_label=-1, background_label=0
    )

    print(f"\nPair {i+1}:")
    print(f"Ground Truth File: {gt_filename}")
    print(f"Inference File: {inf_filename}\n")

    print("Dice scores per label (label: score):")
    for label, score in dice_scores.items():
        if np.isnan(score):
            print(f"  Label {label}: no voxels in GT or Prediction")
        else:
            print(f"  Label {label}: {score:.4f}")

        ### ADDED: Accumulate label-wise scores across scans, ignoring NaN
        if not np.isnan(score):
            if label not in aggregate_scores:
                aggregate_scores[label] = []
            aggregate_scores[label].append(score)

    if np.isnan(avg_foreground_dice):
        print("Average Foreground Dice (excluding -1 and 0): no valid foreground labels")
    else:
        print(f"Average Foreground Dice (excluding -1 and 0): {avg_foreground_dice:.4f}")

# ----------------------------------------------------------------------
# 6) After processing all scans, compute single list of average Dice scores
# ----------------------------------------------------------------------
print("\n=========================================")
print("Final AVERAGE Dice score per label (across ALL scans):")

final_scores = {}
for label, values in aggregate_scores.items():
    final_scores[label] = np.mean(values)  # average over all scans that had that label

# Sort in descending order by Dice
sorted_final = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)

print("Label | Class Name                       | Dice")
print("------|----------------------------------|----------")

for label, score in sorted_final:
    # Convert label to int for printing if needed
    label_name = next(
        (k for k, v in label_correspondence["labels"].items() if v == label),
        "???"
    )
    print(f"{int(label):5d} | {label_name:30s} | {score:.4f}")
# Out:
# Pair 1:
# Ground Truth File: Afterthought-1.nii.gz
# Inference File: bobs_0000.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9650
#   Label 3.0: 0.6066
#   Label 4.0: 0.8657
#   Label 5.0: 0.4786
#   Label 7.0: 0.2309
#   Label 9.0: 0.1791
#   Label 10.0: 0.2388
#   Label 11.0: 0.0485
#   Label 12.0: 0.0794
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0017
#   Label 16.0: 0.0077
#   Label 17.0: 0.3323
#   Label 18.0: 0.7041
#   Label 19.0: 0.5073
#   Label 20.0: 0.0000
#   Label 22.0: 0.7485
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2794
#
# Pair 2:
# Ground Truth File: Colin27-1.nii.gz
# Inference File: bobs_0001.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9789
#   Label 3.0: 0.7493
#   Label 4.0: 0.8263
#   Label 5.0: 0.6548
#   Label 7.0: 0.6544
#   Label 9.0: 0.3529
#   Label 10.0: 0.2737
#   Label 11.0: 0.3607
#   Label 12.0: 0.1239
#   Label 13.0: 0.0000
#   Label 14.0: 0.0034
#   Label 15.0: 0.0001
#   Label 16.0: 0.2750
#   Label 17.0: 0.5916
#   Label 18.0: 0.4142
#   Label 19.0: 0.1967
#   Label 20.0: 0.0000
#   Label 22.0: 0.6194
#   Label 24.0: 0.4014
# Average Foreground Dice (excluding -1 and 0): 0.3610
#
# Pair 3:
# Ground Truth File: HLN-12-1.nii.gz
# Inference File: bobs_0002.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.8177
#   Label 3.0: 0.3712
#   Label 4.0: 0.3075
#   Label 5.0: 0.1823
#   Label 7.0: 0.1168
#   Label 9.0: 0.3013
#   Label 10.0: 0.0582
#   Label 11.0: 0.3037
#   Label 12.0: 0.0752
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0021
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2337
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1084
#
# Pair 4:
# Ground Truth File: HLN-12-10.nii.gz
# Inference File: bobs_0003.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9061
#   Label 3.0: 0.4354
#   Label 4.0: 0.5023
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0874
#   Label 10.0: 0.1008
#   Label 11.0: 0.2318
#   Label 12.0: 0.2696
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0078
#   Label 17.0: 0.0045
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.1359
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0986
#
# Pair 5:
# Ground Truth File: HLN-12-11.nii.gz
# Inference File: bobs_0004.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9156
#   Label 3.0: 0.4639
#   Label 4.0: 0.5527
#   Label 5.0: 0.0204
#   Label 7.0: 0.0000
#   Label 9.0: 0.1604
#   Label 10.0: 0.0793
#   Label 11.0: 0.1885
#   Label 12.0: 0.2940
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0163
#   Label 17.0: 0.0005
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.1800
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1087
#
# Pair 6:
# Ground Truth File: HLN-12-12.nii.gz
# Inference File: bobs_0005.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9008
#   Label 3.0: 0.4212
#   Label 4.0: 0.4595
#   Label 5.0: 0.0345
#   Label 7.0: 0.0000
#   Label 9.0: 0.0162
#   Label 10.0: 0.0550
#   Label 11.0: 0.1105
#   Label 12.0: 0.1415
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0173
#   Label 17.0: 0.0056
#   Label 18.0: 0.0110
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.1862
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0810
#
# Pair 7:
# Ground Truth File: HLN-12-2.nii.gz
# Inference File: bobs_0006.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.8450
#   Label 3.0: 0.4403
#   Label 4.0: 0.5239
#   Label 5.0: 0.0582
#   Label 7.0: 0.0000
#   Label 9.0: 0.4096
#   Label 10.0: 0.1679
#   Label 11.0: 0.0805
#   Label 12.0: 0.1938
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0012
#   Label 17.0: 0.0096
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2862
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1206
#
# Pair 8:
# Ground Truth File: HLN-12-3.nii.gz
# Inference File: bobs_0007.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9353
#   Label 3.0: 0.4899
#   Label 4.0: 0.5120
#   Label 5.0: 0.0070
#   Label 7.0: 0.0897
#   Label 9.0: 0.1624
#   Label 10.0: 0.1001
#   Label 11.0: 0.2047
#   Label 12.0: 0.2560
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0107
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2722
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1169
#
# Pair 9:
# Ground Truth File: HLN-12-4.nii.gz
# Inference File: bobs_0008.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9636
#   Label 3.0: 0.5089
#   Label 4.0: 0.5591
#   Label 5.0: 0.0000
#   Label 7.0: 0.0004
#   Label 9.0: 0.3271
#   Label 10.0: 0.1885
#   Label 11.0: 0.1896
#   Label 12.0: 0.1643
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0525
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2209
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1228
#
# Pair 10:
# Ground Truth File: HLN-12-5.nii.gz
# Inference File: bobs_0009.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.8863
#   Label 3.0: 0.4419
#   Label 4.0: 0.4074
#   Label 5.0: 0.0200
#   Label 7.0: 0.0000
#   Label 9.0: 0.6021
#   Label 10.0: 0.3346
#   Label 11.0: 0.1858
#   Label 12.0: 0.2776
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0045
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.1808
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1364
#
# Pair 11:
# Ground Truth File: HLN-12-6.nii.gz
# Inference File: bobs_0010.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.8509
#   Label 3.0: 0.4178
#   Label 4.0: 0.3917
#   Label 5.0: 0.0594
#   Label 7.0: 0.0108
#   Label 9.0: 0.2893
#   Label 10.0: 0.1915
#   Label 11.0: 0.3048
#   Label 12.0: 0.2697
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0029
#   Label 17.0: 0.0014
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2083
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1193
#
# Pair 12:
# Ground Truth File: HLN-12-7.nii.gz
# Inference File: bobs_0011.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9604
#   Label 3.0: 0.5523
#   Label 4.0: 0.3345
#   Label 5.0: 0.0369
#   Label 7.0: 0.0000
#   Label 9.0: 0.4140
#   Label 10.0: 0.1014
#   Label 11.0: 0.1963
#   Label 12.0: 0.3186
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0068
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2432
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1224
#
# Pair 13:
# Ground Truth File: HLN-12-8.nii.gz
# Inference File: bobs_0012.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9548
#   Label 3.0: 0.5178
#   Label 4.0: 0.4501
#   Label 5.0: 0.0723
#   Label 7.0: 0.0001
#   Label 9.0: 0.5914
#   Label 10.0: 0.0853
#   Label 11.0: 0.0626
#   Label 12.0: 0.2289
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0050
#   Label 17.0: 0.0004
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.1696
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1213
#
# Pair 14:
# Ground Truth File: HLN-12-9.nii.gz
# Inference File: bobs_0013.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9243
#   Label 3.0: 0.4740
#   Label 4.0: 0.3300
#   Label 5.0: 0.0748
#   Label 7.0: 0.0002
#   Label 9.0: 0.5410
#   Label 10.0: 0.1113
#   Label 11.0: 0.1701
#   Label 12.0: 0.2916
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0794
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.2958
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1316
#
# Pair 15:
# Ground Truth File: MMRR-21-1.nii.gz
# Inference File: bobs_0014.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9630
#   Label 3.0: 0.4493
#   Label 4.0: 0.2804
#   Label 5.0: 0.5236
#   Label 7.0: 0.6155
#   Label 9.0: 0.5569
#   Label 10.0: 0.2009
#   Label 11.0: 0.1814
#   Label 12.0: 0.3003
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0044
#   Label 16.0: 0.0558
#   Label 17.0: 0.2182
#   Label 18.0: 0.7821
#   Label 19.0: 0.0420
#   Label 20.0: 0.0000
#   Label 22.0: 0.7905
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2779
#
# Pair 16:
# Ground Truth File: MMRR-21-10.nii.gz
# Inference File: bobs_0015.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9425
#   Label 3.0: 0.4279
#   Label 4.0: 0.4389
#   Label 5.0: 0.5915
#   Label 7.0: 0.3982
#   Label 9.0: 0.4868
#   Label 10.0: 0.1257
#   Label 11.0: 0.0287
#   Label 12.0: 0.1616
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0059
#   Label 16.0: 0.0032
#   Label 17.0: 0.1850
#   Label 18.0: 0.6811
#   Label 19.0: 0.2111
#   Label 20.0: 0.0000
#   Label 22.0: 0.7641
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2505
#
# Pair 17:
# Ground Truth File: MMRR-21-11.nii.gz
# Inference File: bobs_0016.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9620
#   Label 3.0: 0.5323
#   Label 4.0: 0.7261
#   Label 5.0: 0.4148
#   Label 7.0: 0.3679
#   Label 9.0: 0.5111
#   Label 10.0: 0.2665
#   Label 11.0: 0.1969
#   Label 12.0: 0.2212
#   Label 13.0: 0.0000
#   Label 14.0: 0.0007
#   Label 15.0: 0.0011
#   Label 16.0: 0.0330
#   Label 17.0: 0.2648
#   Label 18.0: 0.7652
#   Label 19.0: 0.4082
#   Label 20.0: 0.0000
#   Label 22.0: 0.7213
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3017
#
# Pair 18:
# Ground Truth File: MMRR-21-12.nii.gz
# Inference File: bobs_0017.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9713
#   Label 3.0: 0.5192
#   Label 4.0: 0.7275
#   Label 5.0: 0.3945
#   Label 7.0: 0.7377
#   Label 9.0: 0.6128
#   Label 10.0: 0.2691
#   Label 11.0: 0.1004
#   Label 12.0: 0.0869
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0035
#   Label 16.0: 0.0624
#   Label 17.0: 0.1777
#   Label 18.0: 0.7993
#   Label 19.0: 0.4346
#   Label 20.0: 0.0000
#   Label 22.0: 0.7328
#   Label 24.0: 0.1639
# Average Foreground Dice (excluding -1 and 0): 0.3235
#
# Pair 19:
# Ground Truth File: MMRR-21-13.nii.gz
# Inference File: bobs_0018.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9516
#   Label 3.0: 0.4163
#   Label 4.0: 0.7650
#   Label 5.0: 0.4791
#   Label 7.0: 0.5884
#   Label 9.0: 0.5624
#   Label 10.0: 0.1507
#   Label 11.0: 0.0386
#   Label 12.0: 0.1221
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0008
#   Label 16.0: 0.0123
#   Label 17.0: 0.2057
#   Label 18.0: 0.6345
#   Label 19.0: 0.3256
#   Label 20.0: 0.0000
#   Label 22.0: 0.7715
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2818
#
# Pair 20:
# Ground Truth File: MMRR-21-14.nii.gz
# Inference File: bobs_0019.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9336
#   Label 3.0: 0.3145
#   Label 4.0: 0.3699
#   Label 5.0: 0.3151
#   Label 7.0: 0.1344
#   Label 9.0: 0.4796
#   Label 10.0: 0.2800
#   Label 11.0: 0.0962
#   Label 12.0: 0.2868
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0011
#   Label 16.0: 0.0003
#   Label 17.0: 0.1246
#   Label 18.0: 0.7289
#   Label 19.0: 0.0311
#   Label 20.0: 0.0000
#   Label 22.0: 0.7689
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2184
#
# Pair 21:
# Ground Truth File: MMRR-21-15.nii.gz
# Inference File: bobs_0020.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9632
#   Label 3.0: 0.4330
#   Label 4.0: 0.6332
#   Label 5.0: 0.4372
#   Label 7.0: 0.5086
#   Label 9.0: 0.5878
#   Label 10.0: 0.3109
#   Label 11.0: 0.2295
#   Label 12.0: 0.2818
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0022
#   Label 16.0: 0.0606
#   Label 17.0: 0.2270
#   Label 18.0: 0.7397
#   Label 19.0: 0.1576
#   Label 20.0: 0.0000
#   Label 22.0: 0.7813
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2995
#
# Pair 22:
# Ground Truth File: MMRR-21-16.nii.gz
# Inference File: bobs_0021.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9386
#   Label 3.0: 0.3994
#   Label 4.0: 0.7426
#   Label 5.0: 0.5970
#   Label 7.0: 0.6366
#   Label 9.0: 0.4280
#   Label 10.0: 0.0272
#   Label 11.0: 0.0063
#   Label 12.0: 0.0539
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0032
#   Label 16.0: 0.0091
#   Label 17.0: 0.2039
#   Label 18.0: 0.4981
#   Label 19.0: 0.3659
#   Label 20.0: 0.0000
#   Label 22.0: 0.7764
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2638
#
# Pair 23:
# Ground Truth File: MMRR-21-17.nii.gz
# Inference File: bobs_0022.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9633
#   Label 3.0: 0.5211
#   Label 4.0: 0.6739
#   Label 5.0: 0.7153
#   Label 7.0: 0.2559
#   Label 9.0: 0.2295
#   Label 10.0: 0.1019
#   Label 11.0: 0.0081
#   Label 12.0: 0.1170
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0019
#   Label 16.0: 0.0000
#   Label 17.0: 0.1190
#   Label 18.0: 0.6345
#   Label 19.0: 0.3257
#   Label 20.0: 0.0000
#   Label 22.0: 0.6514
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2420
#
# Pair 24:
# Ground Truth File: MMRR-21-18.nii.gz
# Inference File: bobs_0023.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9782
#   Label 3.0: 0.5729
#   Label 4.0: 0.8171
#   Label 5.0: 0.6207
#   Label 7.0: 0.4577
#   Label 9.0: 0.5340
#   Label 10.0: 0.2084
#   Label 11.0: 0.0687
#   Label 12.0: 0.1437
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0041
#   Label 16.0: 0.0601
#   Label 17.0: 0.3112
#   Label 18.0: 0.4041
#   Label 19.0: 0.3856
#   Label 20.0: 0.0000
#   Label 22.0: 0.7423
#   Label 24.0: 0.1290
# Average Foreground Dice (excluding -1 and 0): 0.3033
#
# Pair 25:
# Ground Truth File: MMRR-21-19.nii.gz
# Inference File: bobs_0024.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9187
#   Label 3.0: 0.2468
#   Label 4.0: 0.5374
#   Label 5.0: 0.2840
#   Label 7.0: 0.0007
#   Label 9.0: 0.4116
#   Label 10.0: 0.1931
#   Label 11.0: 0.0075
#   Label 12.0: 0.2467
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0009
#   Label 16.0: 0.0052
#   Label 17.0: 0.1804
#   Label 18.0: 0.6176
#   Label 19.0: 0.1099
#   Label 20.0: 0.0000
#   Label 22.0: 0.7309
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.1985
#
# Pair 26:
# Ground Truth File: MMRR-21-2.nii.gz
# Inference File: bobs_0025.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9489
#   Label 3.0: 0.3832
#   Label 4.0: 0.7554
#   Label 5.0: 0.4626
#   Label 7.0: 0.5554
#   Label 9.0: 0.4439
#   Label 10.0: 0.2206
#   Label 11.0: 0.0154
#   Label 12.0: 0.1016
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0023
#   Label 16.0: 0.0209
#   Label 17.0: 0.2519
#   Label 18.0: 0.5801
#   Label 19.0: 0.3536
#   Label 20.0: 0.0000
#   Label 22.0: 0.7568
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2724
#
# Pair 27:
# Ground Truth File: MMRR-21-20.nii.gz
# Inference File: bobs_0026.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9752
#   Label 3.0: 0.5578
#   Label 4.0: 0.6091
#   Label 5.0: 0.2551
#   Label 7.0: 0.7766
#   Label 9.0: 0.6771
#   Label 10.0: 0.3999
#   Label 11.0: 0.3005
#   Label 12.0: 0.2975
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0041
#   Label 16.0: 0.1186
#   Label 17.0: 0.2797
#   Label 18.0: 0.8331
#   Label 19.0: 0.0737
#   Label 20.0: 0.0000
#   Label 22.0: 0.8319
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3342
#
# Pair 28:
# Ground Truth File: MMRR-21-21.nii.gz
# Inference File: bobs_0027.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9605
#   Label 3.0: 0.4386
#   Label 4.0: 0.7696
#   Label 5.0: 0.5334
#   Label 7.0: 0.7553
#   Label 9.0: 0.1665
#   Label 10.0: 0.1776
#   Label 11.0: 0.0246
#   Label 12.0: 0.1403
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0017
#   Label 16.0: 0.0015
#   Label 17.0: 0.1335
#   Label 18.0: 0.7627
#   Label 19.0: 0.3838
#   Label 20.0: 0.0000
#   Label 22.0: 0.7880
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2821
#
# Pair 29:
# Ground Truth File: MMRR-21-3.nii.gz
# Inference File: bobs_0028.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9556
#   Label 3.0: 0.3920
#   Label 4.0: 0.5184
#   Label 5.0: 0.2772
#   Label 7.0: 0.3137
#   Label 9.0: 0.5496
#   Label 10.0: 0.2597
#   Label 11.0: 0.0746
#   Label 12.0: 0.1144
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0020
#   Label 16.0: 0.0045
#   Label 17.0: 0.1908
#   Label 18.0: 0.7165
#   Label 19.0: 0.3088
#   Label 20.0: 0.0000
#   Label 22.0: 0.7960
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2510
#
# Pair 30:
# Ground Truth File: MMRR-21-4.nii.gz
# Inference File: bobs_0029.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9601
#   Label 3.0: 0.4673
#   Label 4.0: 0.6787
#   Label 5.0: 0.4851
#   Label 7.0: 0.7323
#   Label 9.0: 0.4591
#   Label 10.0: 0.1496
#   Label 11.0: 0.0679
#   Label 12.0: 0.2067
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0056
#   Label 16.0: 0.0432
#   Label 17.0: 0.1602
#   Label 18.0: 0.4637
#   Label 19.0: 0.2956
#   Label 20.0: 0.0000
#   Label 22.0: 0.7751
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2772
#
# Pair 31:
# Ground Truth File: MMRR-21-5.nii.gz
# Inference File: bobs_0030.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.8682
#   Label 3.0: 0.2475
#   Label 4.0: 0.7110
#   Label 5.0: 0.6585
#   Label 7.0: 0.5923
#   Label 9.0: 0.5920
#   Label 10.0: 0.2625
#   Label 11.0: 0.1639
#   Label 12.0: 0.2031
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0023
#   Label 16.0: 0.0227
#   Label 17.0: 0.1917
#   Label 18.0: 0.7204
#   Label 19.0: 0.1715
#   Label 20.0: 0.0000
#   Label 22.0: 0.7893
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2960
#
# Pair 32:
# Ground Truth File: MMRR-21-6.nii.gz
# Inference File: bobs_0031.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9578
#   Label 3.0: 0.5090
#   Label 4.0: 0.7761
#   Label 5.0: 0.5415
#   Label 7.0: 0.3660
#   Label 9.0: 0.6008
#   Label 10.0: 0.2935
#   Label 11.0: 0.0685
#   Label 12.0: 0.1613
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0029
#   Label 16.0: 0.0859
#   Label 17.0: 0.2320
#   Label 18.0: 0.7580
#   Label 19.0: 0.4505
#   Label 20.0: 0.0000
#   Label 22.0: 0.7582
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3113
#
# Pair 33:
# Ground Truth File: MMRR-21-7.nii.gz
# Inference File: bobs_0032.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9167
#   Label 3.0: 0.3239
#   Label 4.0: 0.7478
#   Label 5.0: 0.6211
#   Label 7.0: 0.6154
#   Label 9.0: 0.5784
#   Label 10.0: 0.1660
#   Label 11.0: 0.0279
#   Label 12.0: 0.1425
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0029
#   Label 16.0: 0.0046
#   Label 17.0: 0.1532
#   Label 18.0: 0.5190
#   Label 19.0: 0.3415
#   Label 20.0: 0.0000
#   Label 22.0: 0.7678
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2784
#
# Pair 34:
# Ground Truth File: MMRR-21-8.nii.gz
# Inference File: bobs_0033.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9654
#   Label 3.0: 0.3992
#   Label 4.0: 0.4466
#   Label 5.0: 0.4810
#   Label 7.0: 0.4318
#   Label 9.0: 0.5786
#   Label 10.0: 0.2022
#   Label 11.0: 0.0992
#   Label 12.0: 0.0552
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0079
#   Label 16.0: 0.0074
#   Label 17.0: 0.1766
#   Label 18.0: 0.5594
#   Label 19.0: 0.3169
#   Label 20.0: 0.0000
#   Label 22.0: 0.7251
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2493
#
# Pair 35:
# Ground Truth File: MMRR-21-9.nii.gz
# Inference File: bobs_0034.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9301
#   Label 3.0: 0.3740
#   Label 4.0: 0.7898
#   Label 5.0: 0.2761
#   Label 7.0: 0.4804
#   Label 9.0: 0.5485
#   Label 10.0: 0.2680
#   Label 11.0: 0.1068
#   Label 12.0: 0.2875
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0020
#   Label 16.0: 0.0494
#   Label 17.0: 0.2466
#   Label 18.0: 0.7178
#   Label 19.0: 0.2802
#   Label 20.0: 0.0000
#   Label 22.0: 0.8028
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2905
#
# Pair 36:
# Ground Truth File: MMRR-3T7T-2-1.nii.gz
# Inference File: bobs_0035.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9753
#   Label 3.0: 0.3517
#   Label 4.0: 0.1291
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0000
#   Label 12.0: 0.1260
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0438
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0361
#
# Pair 37:
# Ground Truth File: MMRR-3T7T-2-2.nii.gz
# Inference File: bobs_0036.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9595
#   Label 3.0: 0.3060
#   Label 4.0: 0.3391
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0001
#   Label 10.0: 0.0632
#   Label 11.0: 0.0000
#   Label 12.0: 0.2579
#   Label 13.0: 0.0075
#   Label 14.0: 0.0000
#   Label 15.0: 0.0003
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0525
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0570
#
# Pair 38:
# Ground Truth File: NKI-RS-22-1.nii.gz
# Inference File: bobs_0037.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9960
#   Label 3.0: 0.8690
#   Label 4.0: 0.8810
#   Label 5.0: 0.4344
#   Label 7.0: 0.5364
#   Label 9.0: 0.3258
#   Label 10.0: 0.2287
#   Label 11.0: 0.0035
#   Label 12.0: 0.0517
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0013
#   Label 16.0: 0.1547
#   Label 17.0: 0.3432
#   Label 18.0: 0.8103
#   Label 19.0: 0.4931
#   Label 20.0: 0.0000
#   Label 22.0: 0.7188
#   Label 24.0: 0.4636
# Average Foreground Dice (excluding -1 and 0): 0.3509
#
# Pair 39:
# Ground Truth File: NKI-RS-22-10.nii.gz
# Inference File: bobs_0038.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9938
#   Label 3.0: 0.8356
#   Label 4.0: 0.8875
#   Label 5.0: 0.6511
#   Label 7.0: 0.6313
#   Label 9.0: 0.5925
#   Label 10.0: 0.3117
#   Label 11.0: 0.0586
#   Label 12.0: 0.1480
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0017
#   Label 16.0: 0.0094
#   Label 17.0: 0.3507
#   Label 18.0: 0.7456
#   Label 19.0: 0.6427
#   Label 20.0: 0.0000
#   Label 22.0: 0.7616
#   Label 24.0: 0.0442
# Average Foreground Dice (excluding -1 and 0): 0.3707
#
# Pair 40:
# Ground Truth File: NKI-RS-22-11.nii.gz
# Inference File: bobs_0039.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9957
#   Label 3.0: 0.8521
#   Label 4.0: 0.8612
#   Label 5.0: 0.6307
#   Label 7.0: 0.4265
#   Label 9.0: 0.5352
#   Label 10.0: 0.2348
#   Label 11.0: 0.0030
#   Label 12.0: 0.0518
#   Label 13.0: 0.0000
#   Label 14.0: 0.0010
#   Label 15.0: 0.0001
#   Label 16.0: 0.0396
#   Label 17.0: 0.3688
#   Label 18.0: 0.8394
#   Label 19.0: 0.5617
#   Label 20.0: 0.0000
#   Label 22.0: 0.7635
#   Label 24.0: 0.3495
# Average Foreground Dice (excluding -1 and 0): 0.3622
#
# Pair 41:
# Ground Truth File: NKI-RS-22-12.nii.gz
# Inference File: bobs_0040.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9904
#   Label 3.0: 0.8103
#   Label 4.0: 0.8376
#   Label 5.0: 0.4585
#   Label 7.0: 0.6106
#   Label 9.0: 0.5470
#   Label 10.0: 0.2579
#   Label 11.0: 0.0743
#   Label 12.0: 0.1479
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0027
#   Label 16.0: 0.0403
#   Label 17.0: 0.2877
#   Label 18.0: 0.6683
#   Label 19.0: 0.5257
#   Label 20.0: 0.0000
#   Label 22.0: 0.7825
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3362
#
# Pair 42:
# Ground Truth File: NKI-RS-22-13.nii.gz
# Inference File: bobs_0041.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9956
#   Label 3.0: 0.8525
#   Label 4.0: 0.8942
#   Label 5.0: 0.1799
#   Label 7.0: 0.7365
#   Label 9.0: 0.6109
#   Label 10.0: 0.3011
#   Label 11.0: 0.1266
#   Label 12.0: 0.2062
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0017
#   Label 16.0: 0.1018
#   Label 17.0: 0.4270
#   Label 18.0: 0.7538
#   Label 19.0: 0.6504
#   Label 20.0: 0.0000
#   Label 22.0: 0.7812
#   Label 24.0: 0.2273
# Average Foreground Dice (excluding -1 and 0): 0.3806
#
# Pair 43:
# Ground Truth File: NKI-RS-22-14.nii.gz
# Inference File: bobs_0042.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9928
#   Label 3.0: 0.8127
#   Label 4.0: 0.7637
#   Label 5.0: 0.6371
#   Label 7.0: 0.7683
#   Label 9.0: 0.6342
#   Label 10.0: 0.2760
#   Label 11.0: 0.1983
#   Label 12.0: 0.1972
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0006
#   Label 16.0: 0.1790
#   Label 17.0: 0.3595
#   Label 18.0: 0.7737
#   Label 19.0: 0.5271
#   Label 20.0: 0.0000
#   Label 22.0: 0.7499
#   Label 24.0: 0.1020
# Average Foreground Dice (excluding -1 and 0): 0.3877
#
# Pair 44:
# Ground Truth File: NKI-RS-22-15.nii.gz
# Inference File: bobs_0043.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9935
#   Label 3.0: 0.8438
#   Label 4.0: 0.8766
#   Label 5.0: 0.0645
#   Label 7.0: 0.2802
#   Label 9.0: 0.4792
#   Label 10.0: 0.2571
#   Label 11.0: 0.0225
#   Label 12.0: 0.1024
#   Label 13.0: 0.0000
#   Label 14.0: 0.0006
#   Label 15.0: 0.0000
#   Label 16.0: 0.1396
#   Label 17.0: 0.2622
#   Label 18.0: 0.5534
#   Label 19.0: 0.1931
#   Label 20.0: 0.0000
#   Label 22.0: 0.6553
#   Label 24.0: 0.2120
# Average Foreground Dice (excluding -1 and 0): 0.2746
#
# Pair 45:
# Ground Truth File: NKI-RS-22-16.nii.gz
# Inference File: bobs_0044.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9967
#   Label 3.0: 0.7868
#   Label 4.0: 0.6023
#   Label 5.0: 0.2895
#   Label 7.0: 0.0000
#   Label 9.0: 0.3775
#   Label 10.0: 0.2915
#   Label 11.0: 0.0756
#   Label 12.0: 0.0497
#   Label 13.0: 0.0000
#   Label 14.0: 0.0081
#   Label 15.0: 0.0000
#   Label 16.0: 0.0018
#   Label 17.0: 0.2339
#   Label 18.0: 0.5851
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.5480
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2139
#
# Pair 46:
# Ground Truth File: NKI-RS-22-17.nii.gz
# Inference File: bobs_0045.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9939
#   Label 3.0: 0.8435
#   Label 4.0: 0.8018
#   Label 5.0: 0.5120
#   Label 7.0: 0.3511
#   Label 9.0: 0.5338
#   Label 10.0: 0.2590
#   Label 11.0: 0.0280
#   Label 12.0: 0.1205
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.1787
#   Label 17.0: 0.2467
#   Label 18.0: 0.7886
#   Label 19.0: 0.5314
#   Label 20.0: 0.0000
#   Label 22.0: 0.7854
#   Label 24.0: 0.5182
# Average Foreground Dice (excluding -1 and 0): 0.3610
#
# Pair 47:
# Ground Truth File: NKI-RS-22-18.nii.gz
# Inference File: bobs_0046.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9917
#   Label 3.0: 0.7971
#   Label 4.0: 0.8656
#   Label 5.0: 0.5392
#   Label 7.0: 0.2437
#   Label 9.0: 0.5411
#   Label 10.0: 0.3164
#   Label 11.0: 0.0682
#   Label 12.0: 0.1439
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.2616
#   Label 17.0: 0.3052
#   Label 18.0: 0.6185
#   Label 19.0: 0.4942
#   Label 20.0: 0.0000
#   Label 22.0: 0.7351
#   Label 24.0: 0.4741
# Average Foreground Dice (excluding -1 and 0): 0.3558
#
# Pair 48:
# Ground Truth File: NKI-RS-22-19.nii.gz
# Inference File: bobs_0047.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9942
#   Label 3.0: 0.8339
#   Label 4.0: 0.8198
#   Label 5.0: 0.6375
#   Label 7.0: 0.2997
#   Label 9.0: 0.4007
#   Label 10.0: 0.3207
#   Label 11.0: 0.0835
#   Label 12.0: 0.0626
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0010
#   Label 16.0: 0.4750
#   Label 17.0: 0.2362
#   Label 18.0: 0.7644
#   Label 19.0: 0.3395
#   Label 20.0: 0.0000
#   Label 22.0: 0.7182
#   Label 24.0: 0.3125
# Average Foreground Dice (excluding -1 and 0): 0.3503
#
# Pair 49:
# Ground Truth File: NKI-RS-22-2.nii.gz
# Inference File: bobs_0048.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9955
#   Label 3.0: 0.8645
#   Label 4.0: 0.8764
#   Label 5.0: 0.6088
#   Label 7.0: 0.3017
#   Label 9.0: 0.6055
#   Label 10.0: 0.3146
#   Label 11.0: 0.1600
#   Label 12.0: 0.1888
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0002
#   Label 16.0: 0.3136
#   Label 17.0: 0.3935
#   Label 18.0: 0.7291
#   Label 19.0: 0.5338
#   Label 20.0: 0.0000
#   Label 22.0: 0.7239
#   Label 24.0: 0.4549
# Average Foreground Dice (excluding -1 and 0): 0.3927
#
# Pair 50:
# Ground Truth File: NKI-RS-22-20.nii.gz
# Inference File: bobs_0049.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9950
#   Label 3.0: 0.8410
#   Label 4.0: 0.8605
#   Label 5.0: 0.7035
#   Label 7.0: 0.2243
#   Label 9.0: 0.5647
#   Label 10.0: 0.2412
#   Label 11.0: 0.1248
#   Label 12.0: 0.1886
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0012
#   Label 16.0: 0.2795
#   Label 17.0: 0.4669
#   Label 18.0: 0.7112
#   Label 19.0: 0.5100
#   Label 20.0: 0.0000
#   Label 22.0: 0.7186
#   Label 24.0: 0.0246
# Average Foreground Dice (excluding -1 and 0): 0.3589
#
# Pair 51:
# Ground Truth File: NKI-RS-22-21.nii.gz
# Inference File: bobs_0050.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9942
#   Label 3.0: 0.8251
#   Label 4.0: 0.6974
#   Label 5.0: 0.6445
#   Label 7.0: 0.4229
#   Label 9.0: 0.5676
#   Label 10.0: 0.2932
#   Label 11.0: 0.1654
#   Label 12.0: 0.2262
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0013
#   Label 16.0: 0.3444
#   Label 17.0: 0.4049
#   Label 18.0: 0.8589
#   Label 19.0: 0.3885
#   Label 20.0: 0.0000
#   Label 22.0: 0.7204
#   Label 24.0: 0.0403
# Average Foreground Dice (excluding -1 and 0): 0.3667
#
# Pair 52:
# Ground Truth File: NKI-RS-22-22.nii.gz
# Inference File: bobs_0051.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9934
#   Label 3.0: 0.7916
#   Label 4.0: 0.7132
#   Label 5.0: 0.5191
#   Label 7.0: 0.2747
#   Label 9.0: 0.4899
#   Label 10.0: 0.2365
#   Label 11.0: 0.0411
#   Label 12.0: 0.0788
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0001
#   Label 16.0: 0.3282
#   Label 17.0: 0.3158
#   Label 18.0: 0.7859
#   Label 19.0: 0.4616
#   Label 20.0: 0.0000
#   Label 22.0: 0.7012
#   Label 24.0: 0.6131
# Average Foreground Dice (excluding -1 and 0): 0.3528
#
# Pair 53:
# Ground Truth File: NKI-RS-22-3.nii.gz
# Inference File: bobs_0052.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9954
#   Label 3.0: 0.8358
#   Label 4.0: 0.6492
#   Label 5.0: 0.6530
#   Label 7.0: 0.7884
#   Label 9.0: 0.6174
#   Label 10.0: 0.2679
#   Label 11.0: 0.0595
#   Label 12.0: 0.1305
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0070
#   Label 16.0: 0.0137
#   Label 17.0: 0.1674
#   Label 18.0: 0.8172
#   Label 19.0: 0.4717
#   Label 20.0: 0.0000
#   Label 22.0: 0.7910
#   Label 24.0: 0.3203
# Average Foreground Dice (excluding -1 and 0): 0.3661
#
# Pair 54:
# Ground Truth File: NKI-RS-22-4.nii.gz
# Inference File: bobs_0053.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9932
#   Label 3.0: 0.8235
#   Label 4.0: 0.8788
#   Label 5.0: 0.7080
#   Label 7.0: 0.5805
#   Label 9.0: 0.4659
#   Label 10.0: 0.1891
#   Label 11.0: 0.0092
#   Label 12.0: 0.1009
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.2446
#   Label 17.0: 0.0725
#   Label 18.0: 0.5724
#   Label 19.0: 0.1718
#   Label 20.0: 0.0000
#   Label 22.0: 0.6739
#   Label 24.0: 0.2075
# Average Foreground Dice (excluding -1 and 0): 0.3166
#
# Pair 55:
# Ground Truth File: NKI-RS-22-5.nii.gz
# Inference File: bobs_0054.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9956
#   Label 3.0: 0.8596
#   Label 4.0: 0.9005
#   Label 5.0: 0.5040
#   Label 7.0: 0.7011
#   Label 9.0: 0.6254
#   Label 10.0: 0.3228
#   Label 11.0: 0.4471
#   Label 12.0: 0.3178
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0019
#   Label 16.0: 0.3214
#   Label 17.0: 0.5485
#   Label 18.0: 0.7537
#   Label 19.0: 0.5248
#   Label 20.0: 0.0000
#   Label 22.0: 0.7535
#   Label 24.0: 0.4324
# Average Foreground Dice (excluding -1 and 0): 0.4453
#
# Pair 56:
# Ground Truth File: NKI-RS-22-6.nii.gz
# Inference File: bobs_0055.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9915
#   Label 3.0: 0.8142
#   Label 4.0: 0.7463
#   Label 5.0: 0.4935
#   Label 7.0: 0.2794
#   Label 9.0: 0.4894
#   Label 10.0: 0.2640
#   Label 11.0: 0.0263
#   Label 12.0: 0.0979
#   Label 13.0: 0.0000
#   Label 14.0: 0.0017
#   Label 15.0: 0.0000
#   Label 16.0: 0.0223
#   Label 17.0: 0.1316
#   Label 18.0: 0.7204
#   Label 19.0: 0.1810
#   Label 20.0: 0.0000
#   Label 22.0: 0.5813
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2694
#
# Pair 57:
# Ground Truth File: NKI-RS-22-7.nii.gz
# Inference File: bobs_0056.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9875
#   Label 3.0: 0.7432
#   Label 4.0: 0.9166
#   Label 5.0: 0.3021
#   Label 7.0: 0.2501
#   Label 9.0: 0.5516
#   Label 10.0: 0.2639
#   Label 11.0: 0.0276
#   Label 12.0: 0.1295
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0008
#   Label 16.0: 0.0815
#   Label 17.0: 0.4000
#   Label 18.0: 0.6296
#   Label 19.0: 0.4124
#   Label 20.0: 0.0000
#   Label 22.0: 0.7199
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3016
#
# Pair 58:
# Ground Truth File: NKI-RS-22-8.nii.gz
# Inference File: bobs_0057.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9931
#   Label 3.0: 0.8395
#   Label 4.0: 0.9023
#   Label 5.0: 0.6520
#   Label 7.0: 0.1357
#   Label 9.0: 0.5446
#   Label 10.0: 0.2924
#   Label 11.0: 0.0281
#   Label 12.0: 0.1116
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.1608
#   Label 17.0: 0.2457
#   Label 18.0: 0.7025
#   Label 19.0: 0.3584
#   Label 20.0: 0.0000
#   Label 22.0: 0.6646
#   Label 24.0: 0.0755
# Average Foreground Dice (excluding -1 and 0): 0.3174
#
# Pair 59:
# Ground Truth File: NKI-RS-22-9.nii.gz
# Inference File: bobs_0058.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9949
#   Label 3.0: 0.8486
#   Label 4.0: 0.8801
#   Label 5.0: 0.5830
#   Label 7.0: 0.6955
#   Label 9.0: 0.3541
#   Label 10.0: 0.2305
#   Label 11.0: 0.0778
#   Label 12.0: 0.1597
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0023
#   Label 16.0: 0.0130
#   Label 17.0: 0.2456
#   Label 18.0: 0.8178
#   Label 19.0: 0.4961
#   Label 20.0: 0.0000
#   Label 22.0: 0.8295
#   Label 24.0: 0.2247
# Average Foreground Dice (excluding -1 and 0): 0.3588
#
# Pair 60:
# Ground Truth File: NKI-TRT-20-1.nii.gz
# Inference File: bobs_0059.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9905
#   Label 3.0: 0.7861
#   Label 4.0: 0.8955
#   Label 5.0: 0.5522
#   Label 7.0: 0.2485
#   Label 9.0: 0.4101
#   Label 10.0: 0.2552
#   Label 11.0: 0.0001
#   Label 12.0: 0.0550
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0007
#   Label 16.0: 0.0201
#   Label 17.0: 0.1981
#   Label 18.0: 0.7849
#   Label 19.0: 0.4411
#   Label 20.0: 0.0000
#   Label 22.0: 0.7528
#   Label 24.0: 0.4413
# Average Foreground Dice (excluding -1 and 0): 0.3245
#
# Pair 61:
# Ground Truth File: NKI-TRT-20-10.nii.gz
# Inference File: bobs_0060.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9695
#   Label 3.0: 0.6258
#   Label 4.0: 0.7909
#   Label 5.0: 0.3020
#   Label 7.0: 0.1120
#   Label 9.0: 0.5284
#   Label 10.0: 0.2353
#   Label 11.0: 0.0102
#   Label 12.0: 0.0638
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0007
#   Label 16.0: 0.0317
#   Label 17.0: 0.2198
#   Label 18.0: 0.7208
#   Label 19.0: 0.5655
#   Label 20.0: 0.0000
#   Label 22.0: 0.7433
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.2750
#
# Pair 62:
# Ground Truth File: NKI-TRT-20-11.nii.gz
# Inference File: bobs_0061.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9903
#   Label 3.0: 0.7784
#   Label 4.0: 0.9073
#   Label 5.0: 0.4608
#   Label 7.0: 0.3116
#   Label 9.0: 0.5439
#   Label 10.0: 0.2098
#   Label 11.0: 0.0007
#   Label 12.0: 0.1346
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0019
#   Label 16.0: 0.0513
#   Label 17.0: 0.3169
#   Label 18.0: 0.5854
#   Label 19.0: 0.4209
#   Label 20.0: 0.0000
#   Label 22.0: 0.7476
#   Label 24.0: 0.0123
# Average Foreground Dice (excluding -1 and 0): 0.3046
#
# Pair 63:
# Ground Truth File: NKI-TRT-20-12.nii.gz
# Inference File: bobs_0062.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9896
#   Label 3.0: 0.7813
#   Label 4.0: 0.8541
#   Label 5.0: 0.4755
#   Label 7.0: 0.3557
#   Label 9.0: 0.3417
#   Label 10.0: 0.2476
#   Label 11.0: 0.0097
#   Label 12.0: 0.0716
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0032
#   Label 16.0: 0.0471
#   Label 17.0: 0.2330
#   Label 18.0: 0.8251
#   Label 19.0: 0.5744
#   Label 20.0: 0.0000
#   Label 22.0: 0.7933
#   Label 24.0: 0.2617
# Average Foreground Dice (excluding -1 and 0): 0.3264
#
# Pair 64:
# Ground Truth File: NKI-TRT-20-13.nii.gz
# Inference File: bobs_0063.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9891
#   Label 3.0: 0.8003
#   Label 4.0: 0.8962
#   Label 5.0: 0.3389
#   Label 7.0: 0.3273
#   Label 9.0: 0.5377
#   Label 10.0: 0.3294
#   Label 11.0: 0.1536
#   Label 12.0: 0.1823
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.1503
#   Label 17.0: 0.2736
#   Label 18.0: 0.7555
#   Label 19.0: 0.5491
#   Label 20.0: 0.0000
#   Label 22.0: 0.8041
#   Label 24.0: 0.5350
# Average Foreground Dice (excluding -1 and 0): 0.3685
#
# Pair 65:
# Ground Truth File: NKI-TRT-20-14.nii.gz
# Inference File: bobs_0064.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9763
#   Label 3.0: 0.6802
#   Label 4.0: 0.7431
#   Label 5.0: 0.6120
#   Label 7.0: 0.7071
#   Label 9.0: 0.6322
#   Label 10.0: 0.2951
#   Label 11.0: 0.1667
#   Label 12.0: 0.1302
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0007
#   Label 16.0: 0.1822
#   Label 17.0: 0.3137
#   Label 18.0: 0.7992
#   Label 19.0: 0.5716
#   Label 20.0: 0.0000
#   Label 22.0: 0.7621
#   Label 24.0: 0.0503
# Average Foreground Dice (excluding -1 and 0): 0.3692
#
# Pair 66:
# Ground Truth File: NKI-TRT-20-15.nii.gz
# Inference File: bobs_0065.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9750
#   Label 3.0: 0.6960
#   Label 4.0: 0.7783
#   Label 5.0: 0.1158
#   Label 7.0: 0.4964
#   Label 9.0: 0.5997
#   Label 10.0: 0.2931
#   Label 11.0: 0.1329
#   Label 12.0: 0.1964
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0008
#   Label 16.0: 0.0225
#   Label 17.0: 0.3131
#   Label 18.0: 0.7666
#   Label 19.0: 0.6718
#   Label 20.0: 0.0000
#   Label 22.0: 0.8000
#   Label 24.0: 0.1284
# Average Foreground Dice (excluding -1 and 0): 0.3340
#
# Pair 67:
# Ground Truth File: NKI-TRT-20-16.nii.gz
# Inference File: bobs_0066.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9904
#   Label 3.0: 0.7733
#   Label 4.0: 0.9042
#   Label 5.0: 0.3338
#   Label 7.0: 0.2465
#   Label 9.0: 0.5002
#   Label 10.0: 0.2112
#   Label 11.0: 0.1709
#   Label 12.0: 0.1715
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0013
#   Label 16.0: 0.1027
#   Label 17.0: 0.3911
#   Label 18.0: 0.6728
#   Label 19.0: 0.3051
#   Label 20.0: 0.0000
#   Label 22.0: 0.7107
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3053
#
# Pair 68:
# Ground Truth File: NKI-TRT-20-17.nii.gz
# Inference File: bobs_0067.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9816
#   Label 3.0: 0.7615
#   Label 4.0: 0.7901
#   Label 5.0: 0.6969
#   Label 7.0: 0.5303
#   Label 9.0: 0.5966
#   Label 10.0: 0.2336
#   Label 11.0: 0.0065
#   Label 12.0: 0.0777
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0046
#   Label 16.0: 0.0936
#   Label 17.0: 0.1321
#   Label 18.0: 0.7606
#   Label 19.0: 0.5905
#   Label 20.0: 0.0000
#   Label 22.0: 0.8210
#   Label 24.0: 0.3017
# Average Foreground Dice (excluding -1 and 0): 0.3554
#
# Pair 69:
# Ground Truth File: NKI-TRT-20-18.nii.gz
# Inference File: bobs_0068.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9855
#   Label 3.0: 0.7296
#   Label 4.0: 0.7154
#   Label 5.0: 0.3354
#   Label 7.0: 0.3591
#   Label 9.0: 0.5875
#   Label 10.0: 0.2849
#   Label 11.0: 0.0908
#   Label 12.0: 0.1895
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0030
#   Label 16.0: 0.0500
#   Label 17.0: 0.2874
#   Label 18.0: 0.8269
#   Label 19.0: 0.4105
#   Label 20.0: 0.0000
#   Label 22.0: 0.7371
#   Label 24.0: 0.2388
# Average Foreground Dice (excluding -1 and 0): 0.3248
#
# Pair 70:
# Ground Truth File: NKI-TRT-20-19.nii.gz
# Inference File: bobs_0069.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9847
#   Label 3.0: 0.7385
#   Label 4.0: 0.7307
#   Label 5.0: 0.4843
#   Label 7.0: 0.6224
#   Label 9.0: 0.6052
#   Label 10.0: 0.1839
#   Label 11.0: 0.0380
#   Label 12.0: 0.1503
#   Label 13.0: 0.0006
#   Label 14.0: 0.0000
#   Label 15.0: 0.0021
#   Label 16.0: 0.0590
#   Label 17.0: 0.3440
#   Label 18.0: 0.7259
#   Label 19.0: 0.5728
#   Label 20.0: 0.0000
#   Label 22.0: 0.8093
#   Label 24.0: 0.2500
# Average Foreground Dice (excluding -1 and 0): 0.3509
#
# Pair 71:
# Ground Truth File: NKI-TRT-20-2.nii.gz
# Inference File: bobs_0070.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9839
#   Label 3.0: 0.7349
#   Label 4.0: 0.8089
#   Label 5.0: 0.4927
#   Label 7.0: 0.4373
#   Label 9.0: 0.6117
#   Label 10.0: 0.2478
#   Label 11.0: 0.1159
#   Label 12.0: 0.1828
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0001
#   Label 16.0: 0.2360
#   Label 17.0: 0.4739
#   Label 18.0: 0.6743
#   Label 19.0: 0.5051
#   Label 20.0: 0.0000
#   Label 22.0: 0.7186
#   Label 24.0: 0.2063
# Average Foreground Dice (excluding -1 and 0): 0.3581
#
# Pair 72:
# Ground Truth File: NKI-TRT-20-20.nii.gz
# Inference File: bobs_0071.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9849
#   Label 3.0: 0.7233
#   Label 4.0: 0.8958
#   Label 5.0: 0.3264
#   Label 7.0: 0.0852
#   Label 9.0: 0.5449
#   Label 10.0: 0.2371
#   Label 11.0: 0.0473
#   Label 12.0: 0.1390
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0003
#   Label 16.0: 0.0479
#   Label 17.0: 0.3105
#   Label 18.0: 0.7380
#   Label 19.0: 0.5872
#   Label 20.0: 0.0000
#   Label 22.0: 0.7992
#   Label 24.0: 0.3458
# Average Foreground Dice (excluding -1 and 0): 0.3238
#
# Pair 73:
# Ground Truth File: NKI-TRT-20-3.nii.gz
# Inference File: bobs_0072.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9813
#   Label 3.0: 0.6976
#   Label 4.0: 0.6657
#   Label 5.0: 0.2440
#   Label 7.0: 0.2712
#   Label 9.0: 0.5060
#   Label 10.0: 0.2185
#   Label 11.0: 0.0172
#   Label 12.0: 0.0755
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0047
#   Label 16.0: 0.0079
#   Label 17.0: 0.2842
#   Label 18.0: 0.7592
#   Label 19.0: 0.2976
#   Label 20.0: 0.0000
#   Label 22.0: 0.7632
#   Label 24.0: 0.1376
# Average Foreground Dice (excluding -1 and 0): 0.2750
#
# Pair 74:
# Ground Truth File: NKI-TRT-20-4.nii.gz
# Inference File: bobs_0073.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9868
#   Label 3.0: 0.7630
#   Label 4.0: 0.8450
#   Label 5.0: 0.6509
#   Label 7.0: 0.3168
#   Label 9.0: 0.3571
#   Label 10.0: 0.1851
#   Label 11.0: 0.0020
#   Label 12.0: 0.0528
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0017
#   Label 16.0: 0.0037
#   Label 17.0: 0.2259
#   Label 18.0: 0.7646
#   Label 19.0: 0.5795
#   Label 20.0: 0.0000
#   Label 22.0: 0.7833
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3073
#
# Pair 75:
# Ground Truth File: NKI-TRT-20-5.nii.gz
# Inference File: bobs_0074.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9892
#   Label 3.0: 0.7560
#   Label 4.0: 0.6395
#   Label 5.0: 0.6456
#   Label 7.0: 0.7822
#   Label 9.0: 0.5928
#   Label 10.0: 0.2856
#   Label 11.0: 0.0496
#   Label 12.0: 0.1270
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0058
#   Label 16.0: 0.0092
#   Label 17.0: 0.1493
#   Label 18.0: 0.8088
#   Label 19.0: 0.4581
#   Label 20.0: 0.0000
#   Label 22.0: 0.7907
#   Label 24.0: 0.2463
# Average Foreground Dice (excluding -1 and 0): 0.3526
#
# Pair 76:
# Ground Truth File: NKI-TRT-20-6.nii.gz
# Inference File: bobs_0075.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9891
#   Label 3.0: 0.7671
#   Label 4.0: 0.9109
#   Label 5.0: 0.4122
#   Label 7.0: 0.1533
#   Label 9.0: 0.6082
#   Label 10.0: 0.2268
#   Label 11.0: 0.0000
#   Label 12.0: 0.0970
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0699
#   Label 17.0: 0.2815
#   Label 18.0: 0.7383
#   Label 19.0: 0.4807
#   Label 20.0: 0.0000
#   Label 22.0: 0.6538
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.3000
#
# Pair 77:
# Ground Truth File: NKI-TRT-20-7.nii.gz
# Inference File: bobs_0076.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9877
#   Label 3.0: 0.7719
#   Label 4.0: 0.8660
#   Label 5.0: 0.5221
#   Label 7.0: 0.5286
#   Label 9.0: 0.6138
#   Label 10.0: 0.3372
#   Label 11.0: 0.1255
#   Label 12.0: 0.1782
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0052
#   Label 16.0: 0.0306
#   Label 17.0: 0.2371
#   Label 18.0: 0.7625
#   Label 19.0: 0.4443
#   Label 20.0: 0.0000
#   Label 22.0: 0.7999
#   Label 24.0: 0.0721
# Average Foreground Dice (excluding -1 and 0): 0.3497
#
# Pair 78:
# Ground Truth File: NKI-TRT-20-8.nii.gz
# Inference File: bobs_0077.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9848
#   Label 3.0: 0.7493
#   Label 4.0: 0.7643
#   Label 5.0: 0.2089
#   Label 7.0: 0.6201
#   Label 9.0: 0.5763
#   Label 10.0: 0.2976
#   Label 11.0: 0.0068
#   Label 12.0: 0.0475
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0004
#   Label 16.0: 0.0165
#   Label 17.0: 0.2470
#   Label 18.0: 0.7498
#   Label 19.0: 0.5341
#   Label 20.0: 0.0000
#   Label 22.0: 0.7762
#   Label 24.0: 0.1667
# Average Foreground Dice (excluding -1 and 0): 0.3201
#
# Pair 79:
# Ground Truth File: NKI-TRT-20-9.nii.gz
# Inference File: bobs_0078.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9827
#   Label 3.0: 0.7251
#   Label 4.0: 0.8640
#   Label 5.0: 0.5621
#   Label 7.0: 0.5574
#   Label 9.0: 0.5836
#   Label 10.0: 0.2884
#   Label 11.0: 0.0137
#   Label 12.0: 0.1082
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0036
#   Label 16.0: 0.0167
#   Label 17.0: 0.2241
#   Label 18.0: 0.8002
#   Label 19.0: 0.4997
#   Label 20.0: 0.0000
#   Label 22.0: 0.7986
#   Label 24.0: 0.1385
# Average Foreground Dice (excluding -1 and 0): 0.3436
#
# Pair 80:
# Ground Truth File: OASIS-TRT-20-1.nii.gz
# Inference File: bobs_0079.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9550
#   Label 3.0: 0.5668
#   Label 4.0: 0.2288
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0033
#   Label 11.0: 0.0026
#   Label 12.0: 0.0013
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0003
#   Label 16.0: 0.0008
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0447
#
# Pair 81:
# Ground Truth File: OASIS-TRT-20-10.nii.gz
# Inference File: bobs_0080.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9741
#   Label 3.0: 0.5311
#   Label 4.0: 0.0351
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0000
#   Label 12.0: 0.0411
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0337
#
# Pair 82:
# Ground Truth File: OASIS-TRT-20-11.nii.gz
# Inference File: bobs_0081.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9722
#   Label 3.0: 0.4662
#   Label 4.0: 0.0183
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0002
#   Label 11.0: 0.0000
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0006
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0270
#
# Pair 83:
# Ground Truth File: OASIS-TRT-20-12.nii.gz
# Inference File: bobs_0082.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9811
#   Label 3.0: 0.6015
#   Label 4.0: 0.3486
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0929
#   Label 11.0: 0.0202
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0591
#
# Pair 84:
# Ground Truth File: OASIS-TRT-20-13.nii.gz
# Inference File: bobs_0083.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9864
#   Label 3.0: 0.6333
#   Label 4.0: 0.1108
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0930
#   Label 11.0: 0.1158
#   Label 12.0: 0.1292
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0002
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0601
#
# Pair 85:
# Ground Truth File: OASIS-TRT-20-14.nii.gz
# Inference File: bobs_0084.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9753
#   Label 3.0: 0.5207
#   Label 4.0: 0.0685
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0981
#   Label 11.0: 0.0170
#   Label 12.0: 0.0498
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0012
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0420
#
# Pair 86:
# Ground Truth File: OASIS-TRT-20-15.nii.gz
# Inference File: bobs_0085.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9757
#   Label 3.0: 0.5742
#   Label 4.0: 0.1181
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0987
#   Label 11.0: 0.0123
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0001
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0446
#
# Pair 87:
# Ground Truth File: OASIS-TRT-20-16.nii.gz
# Inference File: bobs_0086.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9661
#   Label 3.0: 0.5975
#   Label 4.0: 0.2264
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0092
#   Label 11.0: 0.0653
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0014
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0500
#
# Pair 88:
# Ground Truth File: OASIS-TRT-20-17.nii.gz
# Inference File: bobs_0087.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9740
#   Label 3.0: 0.5959
#   Label 4.0: 0.0701
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0488
#   Label 11.0: 0.0035
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0399
#
# Pair 89:
# Ground Truth File: OASIS-TRT-20-18.nii.gz
# Inference File: bobs_0088.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9540
#   Label 3.0: 0.4263
#   Label 4.0: 0.0655
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0000
#   Label 12.0: 0.0465
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0010
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0300
#
# Pair 90:
# Ground Truth File: OASIS-TRT-20-19.nii.gz
# Inference File: bobs_0089.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9770
#   Label 3.0: 0.5737
#   Label 4.0: 0.0202
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0089
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0002
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0335
#
# Pair 91:
# Ground Truth File: OASIS-TRT-20-2.nii.gz
# Inference File: bobs_0090.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9754
#   Label 3.0: 0.5453
#   Label 4.0: 0.1516
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0005
#   Label 11.0: 0.0001
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0001
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0388
#
# Pair 92:
# Ground Truth File: OASIS-TRT-20-20.nii.gz
# Inference File: bobs_0091.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9761
#   Label 3.0: 0.5503
#   Label 4.0: 0.0514
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0211
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0346
#
# Pair 93:
# Ground Truth File: OASIS-TRT-20-3.nii.gz
# Inference File: bobs_0092.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9200
#   Label 3.0: 0.4249
#   Label 4.0: 0.2212
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0162
#   Label 11.0: 0.0778
#   Label 12.0: 0.0356
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0003
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0431
#
# Pair 94:
# Ground Truth File: OASIS-TRT-20-4.nii.gz
# Inference File: bobs_0093.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9720
#   Label 3.0: 0.5557
#   Label 4.0: 0.0010
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0069
#   Label 12.0: 0.0739
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0354
#
# Pair 95:
# Ground Truth File: OASIS-TRT-20-5.nii.gz
# Inference File: bobs_0094.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9691
#   Label 3.0: 0.5473
#   Label 4.0: 0.0722
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0091
#   Label 11.0: 0.0009
#   Label 12.0: 0.0057
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0353
#
# Pair 96:
# Ground Truth File: OASIS-TRT-20-6.nii.gz
# Inference File: bobs_0095.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9582
#   Label 3.0: 0.5380
#   Label 4.0: 0.1324
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0003
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0373
#
# Pair 97:
# Ground Truth File: OASIS-TRT-20-7.nii.gz
# Inference File: bobs_0096.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9557
#   Label 3.0: 0.4045
#   Label 4.0: 0.0927
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0000
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0001
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0276
#
# Pair 98:
# Ground Truth File: OASIS-TRT-20-8.nii.gz
# Inference File: bobs_0097.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9706
#   Label 3.0: 0.5184
#   Label 4.0: 0.0064
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0007
#   Label 11.0: 0.0122
#   Label 12.0: 0.0009
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0007
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0300
#
# Pair 99:
# Ground Truth File: OASIS-TRT-20-9.nii.gz
# Inference File: bobs_0098.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9716
#   Label 3.0: 0.5280
#   Label 4.0: 0.0133
#   Label 5.0: 0.0000
#   Label 7.0: 0.0000
#   Label 9.0: 0.0000
#   Label 10.0: 0.0000
#   Label 11.0: 0.0000
#   Label 12.0: 0.0000
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.0000
#   Label 17.0: 0.0000
#   Label 18.0: 0.0000
#   Label 19.0: 0.0000
#   Label 20.0: 0.0000
#   Label 22.0: 0.0000
#   Label 24.0: 0.0000
# Average Foreground Dice (excluding -1 and 0): 0.0301
#
# Pair 100:
# Ground Truth File: Twins-2-1.nii.gz
# Inference File: bobs_0099.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9654
#   Label 3.0: 0.6259
#   Label 4.0: 0.8562
#   Label 5.0: 0.5803
#   Label 7.0: 0.0029
#   Label 9.0: 0.1358
#   Label 10.0: 0.4803
#   Label 11.0: 0.1110
#   Label 12.0: 0.2687
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0000
#   Label 16.0: 0.4268
#   Label 17.0: 0.4140
#   Label 18.0: 0.3837
#   Label 19.0: 0.3194
#   Label 20.0: 0.0000
#   Label 22.0: 0.4645
#   Label 24.0: 0.2595
# Average Foreground Dice (excluding -1 and 0): 0.2961
#
# Pair 101:
# Ground Truth File: Twins-2-2.nii.gz
# Inference File: bobs_0100.nii.gz
#
# Dice scores per label (label: score):
#   Label 0.0: 0.9672
#   Label 3.0: 0.6285
#   Label 4.0: 0.8345
#   Label 5.0: 0.6306
#   Label 7.0: 0.4448
#   Label 9.0: 0.4291
#   Label 10.0: 0.2269
#   Label 11.0: 0.0013
#   Label 12.0: 0.0257
#   Label 13.0: 0.0000
#   Label 14.0: 0.0000
#   Label 15.0: 0.0041
#   Label 16.0: 0.0123
#   Label 17.0: 0.2248
#   Label 18.0: 0.5973
#   Label 19.0: 0.5724
#   Label 20.0: 0.0000
#   Label 22.0: 0.7306
#   Label 24.0: 0.5622
# Average Foreground Dice (excluding -1 and 0): 0.3292
#
# =========================================
# Final AVERAGE Dice score per label (across ALL scans):
# Label | Class Name                       | Dice
# ------|----------------------------------|----------
#     0 | background                     | 0.9655
#     3 | Cerebral-Cortex                | 0.6088
#     4 | Lateral-Ventricle              | 0.5854
#    22 | VentralDC                      | 0.5202
#    18 | CSF                            | 0.4658
#     9 | Thalamus                       | 0.3755
#     5 | Inf-Lat-Vent                   | 0.3273
#     7 | Cerebellum-White-Matter        | 0.2919
#    19 | Accumbens-area                 | 0.2663
#    10 | Caudate                        | 0.1875
#    17 | Amygdala                       | 0.1791
#    12 | Pallidum                       | 0.1309
#    24 | Optic-Chiasm                   | 0.1005
#    11 | Putamen                        | 0.0801
#    16 | Hippocampus                    | 0.0648
#    15 | Brain-Stem                     | 0.0013
#    14 | 4th-Ventricle                  | 0.0002
#    13 | 3rd-Ventricle                  | 0.0001
#    20 | Vessel                         | 0.0000
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import nibabel as nib
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Suppose you already have this label correspondence dictionary:
label_correspondence = {
    "labels": {
        "unknown": -1,
        "background": 0,
        "Left-Cerebral-Exterior": 1,
        "Cerebral-White-Matter": 2,
        "Cerebral-Cortex": 3,
        "Lateral-Ventricle": 4,
        "Inf-Lat-Vent": 5,
        "Left-Cerebellum-Exterior": 6,
        "Cerebellum-White-Matter": 7,
        "Cerebellum-Cortex": 8,
        "Thalamus": 9,
        "Caudate": 10,
        "Putamen": 11,
        "Pallidum": 12,
        "3rd-Ventricle": 13,
        "4th-Ventricle": 14,
        "Brain-Stem": 15,
        "Hippocampus": 16,
        "Amygdala": 17,
        "CSF": 18,
        "Accumbens-area": 19,
        "Vessel": 20,
        "Choroid-plexus": 21,
        "VentralDC": 22,
        "WM-hypointensities": 23,
        "Optic-Chiasm": 24,
        "Vermis": 25
    }
}

def visualize_triplet(input_filepath, gt_filepath, pred_filepath):
    """
    Visualize input, ground truth, and prediction side by side
    with an interactive slider to move through slices.
    Allows the user to select which labels to show in the overlays.
    All other labels are masked out.
    """

    # Load data
    input_img = nib.load(input_filepath)
    input_data = input_img.get_fdata()

    gt_img = nib.load(gt_filepath)
    gt_data = gt_img.get_fdata()

    pred_img = nib.load(pred_filepath)
    pred_data = pred_img.get_fdata()

    # Build a selectable list of labels (including a special "None" and "All" options):
    label_dict = label_correspondence["labels"]
    # We'll store a list of (display_name, actual_label_id)
    # We add special entries for "All" (show all labels) and "None" (show none)
    label_options = [("All labels", "all"), ("None", "none")]
    for lbl_name, lbl_id in label_dict.items():
        label_options.append((f"{lbl_name} ({lbl_id})", lbl_id))

    # Identify the maximum label used (for color normalization, e.g. 25)
    max_label = max(label_dict.values())

    @interact(
        slice_idx=widgets.IntSlider(min=0,
                                    max=input_data.shape[2]-1,
                                    step=1,
                                    value=(input_data.shape[2]-1)//2),
        selected_labels=widgets.SelectMultiple(
            options=label_options,
            description='Labels to show',
            value=["all"],  # default selection is 'All labels'
            rows=10  # adjust how many lines the SelectMultiple widget shows
        )
    )
    def update(slice_idx=0, selected_labels=("all",)):
        # ---------------------------------------------------------
        # 1) Figure setup
        # ---------------------------------------------------------
        fig, axs = plt.subplots(1, 3, figsize=(20, 7))  # bigger figure

        # ---------------------------------------------------------
        # 2) Generate masked overlays for GT and Prediction
        # ---------------------------------------------------------
        # Convert selected_labels (tuple of label_ids or special strings) to a numeric set
        # If 'all' is present, we keep all labels as is
        # If 'none' is present, we show no labels
        # Otherwise, show only the chosen IDs
        all_label_ids = np.array(list(label_dict.values()), dtype=np.int32)
        if "all" in selected_labels:
            masked_gt = gt_data
            masked_pred = pred_data
        elif "none" in selected_labels:
            # everything is masked out
            masked_gt = np.zeros_like(gt_data)
            masked_pred = np.zeros_like(pred_data)
        else:
            # selected_labels is a list of label IDs we want to see
            numeric_labels = []
            for val in selected_labels:
                if isinstance(val, str):
                    continue  # skip 'all' or 'none' if somehow included
                numeric_labels.append(val)

            numeric_labels = np.array(numeric_labels, dtype=gt_data.dtype)

            # We keep only those labels; everything else -> 0
            masked_gt = np.where(np.isin(gt_data, numeric_labels), gt_data, 0)
            masked_pred = np.where(np.isin(pred_data, numeric_labels), pred_data, 0)

        # ---------------------------------------------------------
        # 3) Show the three subplots
        # ---------------------------------------------------------
        # (a) Input
        axs[0].imshow(input_data[:, :, slice_idx], cmap='gray')
        axs[0].set_title('Input')

        # (b) Ground Truth overlay
        axs[1].imshow(input_data[:, :, slice_idx], cmap='gray')
        axs[1].imshow(masked_gt[:, :, slice_idx], cmap='rainbow', alpha=0.5)
        axs[1].set_title('Ground Truth')

        # (c) Prediction overlay
        axs[2].imshow(input_data[:, :, slice_idx], cmap='gray')
        axs[2].imshow(masked_pred[:, :, slice_idx], cmap='rainbow', alpha=0.5)
        axs[2].set_title('Prediction')

        # ---------------------------------------------------------
        # 4) Build the legend
        # ---------------------------------------------------------
        patches = []
        for lbl_name, lbl_id in label_dict.items():
            # We handle the color logic:
            if lbl_id == 0:
                # background
                color = 'black'
            elif lbl_id == -1:
                # unknown
                color = 'lightgray'
            else:
                # color based on normalized label
                color_val = lbl_id / max_label if max_label != 0 else 0
                color = plt.cm.rainbow(color_val)
            patches.append(Patch(facecolor=color, label=f"{lbl_name} ({lbl_id})"))

        axs[2].legend(handles=patches, bbox_to_anchor=(1.05, 1), loc='upper left')

        plt.tight_layout()
        plt.show()

# ----------------------------------------------------------------------
# 7) Example usage: visualize the first triplet
# ----------------------------------------------------------------------
# Suppose you have these variables defined:
#   input_path, minboggle_ground_truth_path, inference_22_path
#   gt_files_sorted, inference_files_sorted
#
# For demonstration, we'll just show the first pair:
input_filename = os.path.join(input_path, gt_files_sorted[0])
gt_filename = os.path.join(minboggle_ground_truth_path, gt_files_sorted[0])
pred_filename = os.path.join(inference_22_path, inference_files_sorted[0])

visualize_triplet(input_filename, gt_filename, pred_filename)
# Out:
# interactive(children=(IntSlider(value=127, description='slice_idx', max=255), SelectMultiple(description='Labe…
